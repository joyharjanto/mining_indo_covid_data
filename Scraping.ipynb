# %%
from tableauscraper import TableauScraper as TS

# %%
url = "https://vaksin.kemkes.go.id/#/scprovinsi"

# %%
ts = TS()
ts.loads(url)
workbook = ts.getWorkbook()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     443             try:
# --> 444                 cnx.do_handshake()
#     445             except OpenSSL.SSL.WantReadError:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1906         result = _lib.SSL_do_handshake(self._ssl)
# -> 1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1638         else:
# -> 1639             _raise_current_error()
#    1640
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     355             server_hostname=hostname,
# --> 356             ssl_context=context)
#     357
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     358         if HAS_SNI and server_hostname is not None:
# --> 359             return context.wrap_socket(sock, server_hostname=server_hostname)
#     360
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     449             except OpenSSL.SSL.Error as e:
# --> 450                 raise ssl.SSLError('bad handshake: %r' % e)
#     451             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='vaksin.kemkes.go.id', port=443): Max retries exceeded with url: /?%3Aembed=y&%3AshowVizHome=no (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-9-3f88cdbd3bac> in <module>()
#       1 ts = TS()
# ----> 2 ts.loads(url)
#       3 workbook = ts.getWorkbook()
#
# ~/anaconda3/lib/python3.7/site-packages/tableauscraper/TableauScraper.py in loads(self, url, params)
#      52     def loads(self, url, params={}):
#      53         api.setSession(self)
# ---> 54         r = api.getTableauViz(self, self.session, url, params)
#      55         soup = BeautifulSoup(r, "html.parser")
#      56
#
# ~/anaconda3/lib/python3.7/site-packages/tableauscraper/api.py in getTableauViz(scraper, session, url, params)
#      33         }
#      34     r = session.get(url, params=params,
# ---> 35                     verify=scraper.verify
#      36                     )
#      37     return r.text
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     523
#     524         kwargs.setdefault('allow_redirects', True)
# --> 525         return self.request('GET', url, **kwargs)
#     526
#     527     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     509             if isinstance(e.reason, _SSLError):
#     510                 # This branch is for urllib3 v1.22 and later.
# --> 511                 raise SSLError(e, request=request)
#     512
#     513             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='vaksin.kemkes.go.id', port=443): Max retries exceeded with url: /?%3Aembed=y&%3AshowVizHome=no (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %%
for t in workbook.worksheets:
    print(f"worksheet name : {t.name}") #show worksheet name

# %%
for t in workbook.worksheets:
    print(t.data) #show dataframe for this worksheet
# Out:
#              Player Unique-alias                     Metric Trim-value  \
# 0                 Wu LeiEspanyol  Shot Creating Actions per 90 minutes
# 1                 Wu LeiEspanyol                                 xA 90
# 2                 Wu LeiEspanyol     Touches in attacking penalty area
# 3                 Wu LeiEspanyol                        Shots Total 90
# 4                 Wu LeiEspanyol                               npxG 90
# 5          VitoloAtlético Madrid  Shot Creating Actions per 90 minutes
# 6          VitoloAtlético Madrid                                 xA 90
# 7          VitoloAtlético Madrid     Touches in attacking penalty area
# 8          VitoloAtlético Madrid                        Shots Total 90
# 9          VitoloAtlético Madrid                               npxG 90
# 10    Vinicius JúniorReal Madrid  Shot Creating Actions per 90 minutes
# 11    Vinicius JúniorReal Madrid                                 xA 90
# 12    Vinicius JúniorReal Madrid     Touches in attacking penalty area
# 13    Vinicius JúniorReal Madrid                        Shots Total 90
# 14    Vinicius JúniorReal Madrid                               npxG 90
# 15         Takefusa KuboMallorca  Shot Creating Actions per 90 minutes
# 16         Takefusa KuboMallorca                                 xA 90
# 17         Takefusa KuboMallorca     Touches in attacking penalty area
# 18         Takefusa KuboMallorca                        Shots Total 90
# 19         Takefusa KuboMallorca                               npxG 90
# 20             Takashi InuiEibar  Shot Creating Actions per 90 minutes
# 21             Takashi InuiEibar                                 xA 90
# 22             Takashi InuiEibar     Touches in attacking penalty area
# 23             Takashi InuiEibar                        Shots Total 90
# 24             Takashi InuiEibar                               npxG 90
# 25           Sergio CanalesBetis  Shot Creating Actions per 90 minutes
# 26           Sergio CanalesBetis                                 xA 90
# 27           Sergio CanalesBetis     Touches in attacking penalty area
# 28           Sergio CanalesBetis                        Shots Total 90
# 29           Sergio CanalesBetis                               npxG 90
# ..                           ...                                   ...
# 235  Ángel CorreaAtlético Madrid  Shot Creating Actions per 90 minutes
# 236  Ángel CorreaAtlético Madrid                                 xA 90
# 237  Ángel CorreaAtlético Madrid     Touches in attacking penalty area
# 238  Ángel CorreaAtlético Madrid                        Shots Total 90
# 239  Ángel CorreaAtlético Madrid                               npxG 90
# 240        Álvaro VadilloGranada  Shot Creating Actions per 90 minutes
# 241        Álvaro VadilloGranada                                 xA 90
# 242        Álvaro VadilloGranada     Touches in attacking penalty area
# 243        Álvaro VadilloGranada                        Shots Total 90
# 244        Álvaro VadilloGranada                               npxG 90
# 245          Adrián LópezOsasuna  Shot Creating Actions per 90 minutes
# 246          Adrián LópezOsasuna                                 xA 90
# 247          Adrián LópezOsasuna     Touches in attacking penalty area
# 248          Adrián LópezOsasuna                        Shots Total 90
# 249          Adrián LópezOsasuna                               npxG 90
# 250         Adri EmbarbaEspanyol  Shot Creating Actions per 90 minutes
# 251         Adri EmbarbaEspanyol                                 xA 90
# 252         Adri EmbarbaEspanyol     Touches in attacking penalty area
# 253         Adri EmbarbaEspanyol                        Shots Total 90
# 254         Adri EmbarbaEspanyol                               npxG 90
# 255   Adnan JanuzajReal Sociedad  Shot Creating Actions per 90 minutes
# 256   Adnan JanuzajReal Sociedad                                 xA 90
# 257   Adnan JanuzajReal Sociedad     Touches in attacking penalty area
# 258   Adnan JanuzajReal Sociedad                        Shots Total 90
# 259   Adnan JanuzajReal Sociedad                               npxG 90
# 260        Lionel MessiBarcelona  Shot Creating Actions per 90 minutes
# 261        Lionel MessiBarcelona                                 xA 90
# 262        Lionel MessiBarcelona     Touches in attacking penalty area
# 263        Lionel MessiBarcelona                        Shots Total 90
# 264        Lionel MessiBarcelona                               npxG 90
#
#                      Metric Trim-alias  \
# 0                Shot creating actions
# 1                     Expected assists
# 2    Touches in attacking penalty area
# 3                          Shots Total
# 4           Non penalty expected goals
# 5                Shot creating actions
# 6                     Expected assists
# 7    Touches in attacking penalty area
# 8                          Shots Total
# 9           Non penalty expected goals
# 10               Shot creating actions
# 11                    Expected assists
# 12   Touches in attacking penalty area
# 13                         Shots Total
# 14          Non penalty expected goals
# 15               Shot creating actions
# 16                    Expected assists
# 17   Touches in attacking penalty area
# 18                         Shots Total
# 19          Non penalty expected goals
# 20               Shot creating actions
# 21                    Expected assists
# 22   Touches in attacking penalty area
# 23                         Shots Total
# 24          Non penalty expected goals
# 25               Shot creating actions
# 26                    Expected assists
# 27   Touches in attacking penalty area
# 28                         Shots Total
# 29          Non penalty expected goals
# ..                                 ...
# 235              Shot creating actions
# 236                   Expected assists
# 237  Touches in attacking penalty area
# 238                        Shots Total
# 239         Non penalty expected goals
# 240              Shot creating actions
# 241                   Expected assists
# 242  Touches in attacking penalty area
# 243                        Shots Total
# 244         Non penalty expected goals
# 245              Shot creating actions
# 246                   Expected assists
# 247  Touches in attacking penalty area
# 248                        Shots Total
# 249         Non penalty expected goals
# 250              Shot creating actions
# 251                   Expected assists
# 252  Touches in attacking penalty area
# 253                        Shots Total
# 254         Non penalty expected goals
# 255              Shot creating actions
# 256                   Expected assists
# 257  Touches in attacking penalty area
# 258                        Shots Total
# 259         Non penalty expected goals
# 260              Shot creating actions
# 261                   Expected assists
# 262  Touches in attacking penalty area
# 263                        Shots Total
# 264         Non penalty expected goals
#
#     Selected player and selected squad-alias ATTR(Age #)-alias  \
# 0                                      False                28
# 1                                      False                28
# 2                                      False                28
# 3                                      False                28
# 4                                      False                28
# 5                                      False                30
# 6                                      False                30
# 7                                      False                30
# 8                                      False                30
# 9                                      False                30
# 10                                     False                20
# 11                                     False                20
# 12                                     False                20
# 13                                     False                20
# 14                                     False                20
# 15                                     False                19
# 16                                     False                19
# 17                                     False                19
# 18                                     False                19
# 19                                     False                19
# 20                                     False                32
# 21                                     False                32
# 22                                     False                32
# 23                                     False                32
# 24                                     False                32
# 25                                     False                29
# 26                                     False                29
# 27                                     False                29
# 28                                     False                29
# 29                                     False                29
# ..                                       ...               ...
# 235                                    False                25
# 236                                    False                25
# 237                                    False                25
# 238                                    False                25
# 239                                    False                25
# 240                                    False                25
# 241                                    False                25
# 242                                    False                25
# 243                                    False                25
# 244                                    False                25
# 245                                    False                32
# 246                                    False                32
# 247                                    False                32
# 248                                    False                32
# 249                                    False                32
# 250                                    False                28
# 251                                    False                28
# 252                                    False                28
# 253                                    False                28
# 254                                    False                28
# 255                                    False                25
# 256                                    False                25
# 257                                    False                25
# 258                                    False                25
# 259                                    False                25
# 260                                     True                33
# 261                                     True                33
# 262                                     True                33
# 263                                     True                33
# 264                                     True                33
#
#                ATTR(Metric Trim)-alias ATTR(Nationality)-alias  \
# 0                Shot creating actions                     CHN
# 1                     Expected assists                     CHN
# 2    Touches in attacking penalty area                     CHN
# 3                          Shots Total                     CHN
# 4           Non penalty expected goals                     CHN
# 5                Shot creating actions                     ESP
# 6                     Expected assists                     ESP
# 7    Touches in attacking penalty area                     ESP
# 8                          Shots Total                     ESP
# 9           Non penalty expected goals                     ESP
# 10               Shot creating actions                     BRA
# 11                    Expected assists                     BRA
# 12   Touches in attacking penalty area                     BRA
# 13                         Shots Total                     BRA
# 14          Non penalty expected goals                     BRA
# 15               Shot creating actions                     JPN
# 16                    Expected assists                     JPN
# 17   Touches in attacking penalty area                     JPN
# 18                         Shots Total                     JPN
# 19          Non penalty expected goals                     JPN
# 20               Shot creating actions                     JPN
# 21                    Expected assists                     JPN
# 22   Touches in attacking penalty area                     JPN
# 23                         Shots Total                     JPN
# 24          Non penalty expected goals                     JPN
# 25               Shot creating actions                     ESP
# 26                    Expected assists                     ESP
# 27   Touches in attacking penalty area                     ESP
# 28                         Shots Total                     ESP
# 29          Non penalty expected goals                     ESP
# ..                                 ...                     ...
# 235              Shot creating actions                     ARG
# 236                   Expected assists                     ARG
# 237  Touches in attacking penalty area                     ARG
# 238                        Shots Total                     ARG
# 239         Non penalty expected goals                     ARG
# 240              Shot creating actions                     ESP
# 241                   Expected assists                     ESP
# 242  Touches in attacking penalty area                     ESP
# 243                        Shots Total                     ESP
# 244         Non penalty expected goals                     ESP
# 245              Shot creating actions                     ESP
# 246                   Expected assists                     ESP
# 247  Touches in attacking penalty area                     ESP
# 248                        Shots Total                     ESP
# 249         Non penalty expected goals                     ESP
# 250              Shot creating actions                     ESP
# 251                   Expected assists                     ESP
# 252  Touches in attacking penalty area                     ESP
# 253                        Shots Total                     ESP
# 254         Non penalty expected goals                     ESP
# 255              Shot creating actions                     BEL
# 256                   Expected assists                     BEL
# 257  Touches in attacking penalty area                     BEL
# 258                        Shots Total                     BEL
# 259         Non penalty expected goals                     BEL
# 260              Shot creating actions                     ARG
# 261                   Expected assists                     ARG
# 262  Touches in attacking penalty area                     ARG
# 263                        Shots Total                     ARG
# 264         Non penalty expected goals                     ARG
#
#     ATTR(Player)-alias ATTR(Squad)-alias AGG(Pivot Values)-alias  \
# 0               Wu Lei          Espanyol                    1.31
# 1               Wu Lei          Espanyol                    0.09
# 2               Wu Lei          Espanyol                 4.86911
# 3               Wu Lei          Espanyol                    2.36
# 4               Wu Lei          Espanyol                    0.29
# 5               Vitolo   Atlético Madrid                    2.86
# 6               Vitolo   Atlético Madrid                    0.11
# 7               Vitolo   Atlético Madrid                 4.47433
# 8               Vitolo   Atlético Madrid                    1.25
# 9               Vitolo   Atlético Madrid                    0.16
# 10     Vinicius Júnior       Real Madrid                     3.7
# 11     Vinicius Júnior       Real Madrid                    0.17
# 12     Vinicius Júnior       Real Madrid                  9.7654
# 13     Vinicius Júnior       Real Madrid                    2.57
# 14     Vinicius Júnior       Real Madrid                    0.28
# 15       Takefusa Kubo          Mallorca                    3.46
# 16       Takefusa Kubo          Mallorca                    0.11
# 17       Takefusa Kubo          Mallorca                 4.00952
# 18       Takefusa Kubo          Mallorca                     2.1
# 19       Takefusa Kubo          Mallorca                    0.11
# 20        Takashi Inui             Eibar                    2.07
# 21        Takashi Inui             Eibar                    0.07
# 22        Takashi Inui             Eibar                 3.21429
# 23        Takashi Inui             Eibar                    1.74
# 24        Takashi Inui             Eibar                    0.18
# 25      Sergio Canales             Betis                    3.93
# 26      Sergio Canales             Betis                    0.16
# 27      Sergio Canales             Betis                 2.81695
# 28      Sergio Canales             Betis                    1.34
# 29      Sergio Canales             Betis                    0.11
# ..                 ...               ...                     ...
# 235       Ángel Correa   Atlético Madrid                    2.79
# 236       Ángel Correa   Atlético Madrid                    0.18
# 237       Ángel Correa   Atlético Madrid                 6.06987
# 238       Ángel Correa   Atlético Madrid                    1.92
# 239       Ángel Correa   Atlético Madrid                    0.29
# 240     Álvaro Vadillo           Granada                    2.88
# 241     Álvaro Vadillo           Granada                    0.12
# 242     Álvaro Vadillo           Granada                  2.6601
# 243     Álvaro Vadillo           Granada                    1.26
# 244     Álvaro Vadillo           Granada                    0.08
# 245       Adrián López           Osasuna                    2.62
# 246       Adrián López           Osasuna                    0.13
# 247       Adrián López           Osasuna                 4.55301
# 248       Adrián López           Osasuna                    1.12
# 249       Adrián López           Osasuna                    0.11
# 250       Adri Embarba          Espanyol                    2.17
# 251       Adri Embarba          Espanyol                    0.12
# 252       Adri Embarba          Espanyol                 2.03501
# 253       Adri Embarba          Espanyol                    2.43
# 254       Adri Embarba          Espanyol                    0.14
# 255      Adnan Januzaj     Real Sociedad                    4.16
# 256      Adnan Januzaj     Real Sociedad                    0.19
# 257      Adnan Januzaj     Real Sociedad                 3.39332
# 258      Adnan Januzaj     Real Sociedad                    1.93
# 259      Adnan Januzaj     Real Sociedad                    0.11
# 260       Lionel Messi         Barcelona                    6.87
# 261       Lionel Messi         Barcelona                    0.48
# 262       Lionel Messi         Barcelona                 6.78125
# 263       Lionel Messi         Barcelona                    4.81
# 264       Lionel Messi         Barcelona                    0.48
#
#     AGG(RANK([Pivot Values]/WINDOW_MAX([Pivot Values])))-alias  \
# 0                                                   52
# 1                                                   38
# 2                                                   10
# 3                                                   13
# 4                                                    5
# 5                                                   22
# 6                                                   33
# 7                                                   14
# 8                                                   47
# 9                                                   24
# 10                                                   9
# 11                                                  15
# 12                                                   1
# 13                                                  10
# 14                                                   8
# 15                                                  12
# 16                                                  33
# 17                                                  19
# 18                                                  18
# 19                                                  39
# 20                                                  43
# 21                                                  42
# 22                                                  34
# 23                                                  28
# 24                                                  21
# 25                                                   7
# 26                                                  17
# 27                                                  39
# 28                                                  42
# 29                                                  39
# ..                                                 ...
# 235                                                 23
# 236                                                 13
# 237                                                  4
# 238                                                 21
# 239                                                  5
# 240                                                 19
# 241                                                 26
# 242                                                 43
# 243                                                 45
# 244                                                 52
# 245                                                 25
# 246                                                 24
# 247                                                 13
# 248                                                 48
# 249                                                 39
# 250                                                 41
# 251                                                 26
# 252                                                 49
# 253                                                 11
# 254                                                 28
# 255                                                  4
# 256                                                 11
# 257                                                 28
# 258                                                 20
# 259                                                 39
# 260                                                  1
# 261                                                  1
# 262                                                  3
# 263                                                  1
# 264                                                  1
#
#     AGG(Positio Compared to max)-value AGG(Positio Compared to max)-alias
# 0                            0.0623946                              0.062
# 1                             0.133333                              0.133
# 2                             0.448461                              0.448
# 3                             0.463895                              0.464
# 4                             0.595745                              0.596
# 5                             0.323777                              0.324
# 6                             0.177778                              0.178
# 7                             0.403991                              0.404
# 8                             0.221007                              0.221
# 9                             0.319149                              0.319
# 10                             0.46543                              0.465
# 11                            0.311111                              0.311
# 12                                   1                              1.000
# 13                            0.509847                              0.510
# 14                            0.574468                              0.574
# 15                            0.424958                              0.425
# 16                            0.177778                              0.178
# 17                            0.351633                              0.352
# 18                            0.407002                              0.407
# 19                            0.212766                              0.213
# 20                            0.190556                              0.191
# 21                           0.0888889                              0.089
# 22                            0.262055                              0.262
# 23                            0.328228                              0.328
# 24                            0.361702                              0.362
# 25                            0.504216                              0.504
# 26                            0.288889                              0.289
# 27                            0.217297                              0.217
# 28                              0.2407                              0.241
# 29                            0.212766                              0.213
# ..                                 ...                                ...
# 235                           0.311973                              0.312
# 236                           0.333333                              0.333
# 237                            0.58372                              0.584
# 238                           0.367615                              0.368
# 239                           0.595745                              0.596
# 240                            0.32715                              0.327
# 241                                0.2                              0.200
# 242                           0.199629                              0.200
# 243                           0.223195                              0.223
# 244                           0.148936                              0.149
# 245                           0.283305                              0.283
# 246                           0.222222                              0.222
# 247                           0.412855                              0.413
# 248                            0.19256                              0.193
# 249                           0.212766                              0.213
# 250                            0.20742                              0.207
# 251                                0.2                              0.200
# 252                           0.129216                              0.129
# 253                           0.479212                              0.479
# 254                           0.276596                              0.277
# 255                           0.543002                              0.543
# 256                           0.355556                              0.356
# 257                           0.282222                              0.282
# 258                           0.369803                              0.370
# 259                           0.212766                              0.213
# 260                                  1                              1.000
# 261                                  1                              1.000
# 262                           0.663853                              0.664
# 263                                  1                              1.000
# 264                                  1                              1.000
#
# [265 rows x 13 columns]
#              Player Unique-alias                Metric Trim-value  \
# 0                 Wu LeiEspanyol    Progressive Carrying Distance
# 1                 Wu LeiEspanyol  Dribbles Completed Successfully
# 2                 Wu LeiEspanyol        Crosses into Penalty Area
# 3                 Wu LeiEspanyol         Passes into Penalty Area
# 4                 Wu LeiEspanyol                       Key Passes
# 5          VitoloAtlético Madrid    Progressive Carrying Distance
# 6          VitoloAtlético Madrid  Dribbles Completed Successfully
# 7          VitoloAtlético Madrid        Crosses into Penalty Area
# 8          VitoloAtlético Madrid         Passes into Penalty Area
# 9          VitoloAtlético Madrid                       Key Passes
# 10    Vinicius JúniorReal Madrid    Progressive Carrying Distance
# 11    Vinicius JúniorReal Madrid  Dribbles Completed Successfully
# 12    Vinicius JúniorReal Madrid        Crosses into Penalty Area
# 13    Vinicius JúniorReal Madrid         Passes into Penalty Area
# 14    Vinicius JúniorReal Madrid                       Key Passes
# 15         Takefusa KuboMallorca    Progressive Carrying Distance
# 16         Takefusa KuboMallorca  Dribbles Completed Successfully
# 17         Takefusa KuboMallorca        Crosses into Penalty Area
# 18         Takefusa KuboMallorca         Passes into Penalty Area
# 19         Takefusa KuboMallorca                       Key Passes
# 20             Takashi InuiEibar    Progressive Carrying Distance
# 21             Takashi InuiEibar  Dribbles Completed Successfully
# 22             Takashi InuiEibar        Crosses into Penalty Area
# 23             Takashi InuiEibar         Passes into Penalty Area
# 24             Takashi InuiEibar                       Key Passes
# 25           Sergio CanalesBetis    Progressive Carrying Distance
# 26           Sergio CanalesBetis  Dribbles Completed Successfully
# 27           Sergio CanalesBetis        Crosses into Penalty Area
# 28           Sergio CanalesBetis         Passes into Penalty Area
# 29           Sergio CanalesBetis                       Key Passes
# ..                           ...                              ...
# 235  Ángel CorreaAtlético Madrid    Progressive Carrying Distance
# 236  Ángel CorreaAtlético Madrid  Dribbles Completed Successfully
# 237  Ángel CorreaAtlético Madrid        Crosses into Penalty Area
# 238  Ángel CorreaAtlético Madrid         Passes into Penalty Area
# 239  Ángel CorreaAtlético Madrid                       Key Passes
# 240        Álvaro VadilloGranada    Progressive Carrying Distance
# 241        Álvaro VadilloGranada  Dribbles Completed Successfully
# 242        Álvaro VadilloGranada        Crosses into Penalty Area
# 243        Álvaro VadilloGranada         Passes into Penalty Area
# 244        Álvaro VadilloGranada                       Key Passes
# 245          Adrián LópezOsasuna    Progressive Carrying Distance
# 246          Adrián LópezOsasuna  Dribbles Completed Successfully
# 247          Adrián LópezOsasuna        Crosses into Penalty Area
# 248          Adrián LópezOsasuna         Passes into Penalty Area
# 249          Adrián LópezOsasuna                       Key Passes
# 250         Adri EmbarbaEspanyol    Progressive Carrying Distance
# 251         Adri EmbarbaEspanyol  Dribbles Completed Successfully
# 252         Adri EmbarbaEspanyol        Crosses into Penalty Area
# 253         Adri EmbarbaEspanyol         Passes into Penalty Area
# 254         Adri EmbarbaEspanyol                       Key Passes
# 255   Adnan JanuzajReal Sociedad    Progressive Carrying Distance
# 256   Adnan JanuzajReal Sociedad  Dribbles Completed Successfully
# 257   Adnan JanuzajReal Sociedad        Crosses into Penalty Area
# 258   Adnan JanuzajReal Sociedad         Passes into Penalty Area
# 259   Adnan JanuzajReal Sociedad                       Key Passes
# 260        Lionel MessiBarcelona    Progressive Carrying Distance
# 261        Lionel MessiBarcelona  Dribbles Completed Successfully
# 262        Lionel MessiBarcelona        Crosses into Penalty Area
# 263        Lionel MessiBarcelona         Passes into Penalty Area
# 264        Lionel MessiBarcelona                       Key Passes
#
#                           Metric Trim-alias  \
# 0    Progressive carrying distance (metres)
# 1           Dribbles completed successfully
# 2                 Crosses into penalty area
# 3                  Passes into penalty area
# 4                                Key passes
# 5    Progressive carrying distance (metres)
# 6           Dribbles completed successfully
# 7                 Crosses into penalty area
# 8                  Passes into penalty area
# 9                                Key passes
# 10   Progressive carrying distance (metres)
# 11          Dribbles completed successfully
# 12                Crosses into penalty area
# 13                 Passes into penalty area
# 14                               Key passes
# 15   Progressive carrying distance (metres)
# 16          Dribbles completed successfully
# 17                Crosses into penalty area
# 18                 Passes into penalty area
# 19                               Key passes
# 20   Progressive carrying distance (metres)
# 21          Dribbles completed successfully
# 22                Crosses into penalty area
# 23                 Passes into penalty area
# 24                               Key passes
# 25   Progressive carrying distance (metres)
# 26          Dribbles completed successfully
# 27                Crosses into penalty area
# 28                 Passes into penalty area
# 29                               Key passes
# ..                                      ...
# 235  Progressive carrying distance (metres)
# 236         Dribbles completed successfully
# 237               Crosses into penalty area
# 238                Passes into penalty area
# 239                              Key passes
# 240  Progressive carrying distance (metres)
# 241         Dribbles completed successfully
# 242               Crosses into penalty area
# 243                Passes into penalty area
# 244                              Key passes
# 245  Progressive carrying distance (metres)
# 246         Dribbles completed successfully
# 247               Crosses into penalty area
# 248                Passes into penalty area
# 249                              Key passes
# 250  Progressive carrying distance (metres)
# 251         Dribbles completed successfully
# 252               Crosses into penalty area
# 253                Passes into penalty area
# 254                              Key passes
# 255  Progressive carrying distance (metres)
# 256         Dribbles completed successfully
# 257               Crosses into penalty area
# 258                Passes into penalty area
# 259                              Key passes
# 260  Progressive carrying distance (metres)
# 261         Dribbles completed successfully
# 262               Crosses into penalty area
# 263                Passes into penalty area
# 264                              Key passes
#
#     Selected player and selected squad-alias ATTR(Age #)-alias  \
# 0                                      False                28
# 1                                      False                28
# 2                                      False                28
# 3                                      False                28
# 4                                      False                28
# 5                                      False                30
# 6                                      False                30
# 7                                      False                30
# 8                                      False                30
# 9                                      False                30
# 10                                     False                20
# 11                                     False                20
# 12                                     False                20
# 13                                     False                20
# 14                                     False                20
# 15                                     False                19
# 16                                     False                19
# 17                                     False                19
# 18                                     False                19
# 19                                     False                19
# 20                                     False                32
# 21                                     False                32
# 22                                     False                32
# 23                                     False                32
# 24                                     False                32
# 25                                     False                29
# 26                                     False                29
# 27                                     False                29
# 28                                     False                29
# 29                                     False                29
# ..                                       ...               ...
# 235                                    False                25
# 236                                    False                25
# 237                                    False                25
# 238                                    False                25
# 239                                    False                25
# 240                                    False                25
# 241                                    False                25
# 242                                    False                25
# 243                                    False                25
# 244                                    False                25
# 245                                    False                32
# 246                                    False                32
# 247                                    False                32
# 248                                    False                32
# 249                                    False                32
# 250                                    False                28
# 251                                    False                28
# 252                                    False                28
# 253                                    False                28
# 254                                    False                28
# 255                                    False                25
# 256                                    False                25
# 257                                    False                25
# 258                                    False                25
# 259                                    False                25
# 260                                     True                33
# 261                                     True                33
# 262                                     True                33
# 263                                     True                33
# 264                                     True                33
#
#                     ATTR(Metric Trim)-alias ATTR(Nationality)-alias  \
# 0    Progressive carrying distance (metres)                     CHN
# 1           Dribbles completed successfully                     CHN
# 2                 Crosses into penalty area                     CHN
# 3                  Passes into penalty area                     CHN
# 4                                Key passes                     CHN
# 5    Progressive carrying distance (metres)                     ESP
# 6           Dribbles completed successfully                     ESP
# 7                 Crosses into penalty area                     ESP
# 8                  Passes into penalty area                     ESP
# 9                                Key passes                     ESP
# 10   Progressive carrying distance (metres)                     BRA
# 11          Dribbles completed successfully                     BRA
# 12                Crosses into penalty area                     BRA
# 13                 Passes into penalty area                     BRA
# 14                               Key passes                     BRA
# 15   Progressive carrying distance (metres)                     JPN
# 16          Dribbles completed successfully                     JPN
# 17                Crosses into penalty area                     JPN
# 18                 Passes into penalty area                     JPN
# 19                               Key passes                     JPN
# 20   Progressive carrying distance (metres)                     JPN
# 21          Dribbles completed successfully                     JPN
# 22                Crosses into penalty area                     JPN
# 23                 Passes into penalty area                     JPN
# 24                               Key passes                     JPN
# 25   Progressive carrying distance (metres)                     ESP
# 26          Dribbles completed successfully                     ESP
# 27                Crosses into penalty area                     ESP
# 28                 Passes into penalty area                     ESP
# 29                               Key passes                     ESP
# ..                                      ...                     ...
# 235  Progressive carrying distance (metres)                     ARG
# 236         Dribbles completed successfully                     ARG
# 237               Crosses into penalty area                     ARG
# 238                Passes into penalty area                     ARG
# 239                              Key passes                     ARG
# 240  Progressive carrying distance (metres)                     ESP
# 241         Dribbles completed successfully                     ESP
# 242               Crosses into penalty area                     ESP
# 243                Passes into penalty area                     ESP
# 244                              Key passes                     ESP
# 245  Progressive carrying distance (metres)                     ESP
# 246         Dribbles completed successfully                     ESP
# 247               Crosses into penalty area                     ESP
# 248                Passes into penalty area                     ESP
# 249                              Key passes                     ESP
# 250  Progressive carrying distance (metres)                     ESP
# 251         Dribbles completed successfully                     ESP
# 252               Crosses into penalty area                     ESP
# 253                Passes into penalty area                     ESP
# 254                              Key passes                     ESP
# 255  Progressive carrying distance (metres)                     BEL
# 256         Dribbles completed successfully                     BEL
# 257               Crosses into penalty area                     BEL
# 258                Passes into penalty area                     BEL
# 259                              Key passes                     BEL
# 260  Progressive carrying distance (metres)                     ARG
# 261         Dribbles completed successfully                     ARG
# 262               Crosses into penalty area                     ARG
# 263                Passes into penalty area                     ARG
# 264                              Key passes                     ARG
#
#     ATTR(Player)-alias ATTR(Squad)-alias AGG(Pivot Values)-alias  \
# 0               Wu Lei          Espanyol                 67.7487
# 1               Wu Lei          Espanyol                0.890052
# 2               Wu Lei          Espanyol                0.157068
# 3               Wu Lei          Espanyol                0.314136
# 4               Wu Lei          Espanyol                0.680628
# 5               Vitolo   Atlético Madrid                 171.565
# 6               Vitolo   Atlético Madrid                 2.64059
# 7               Vitolo   Atlético Madrid                       0
# 8               Vitolo   Atlético Madrid                0.880196
# 9               Vitolo   Atlético Madrid                 1.02689
# 10     Vinicius Júnior       Real Madrid                 294.282
# 11     Vinicius Júnior       Real Madrid                 3.49707
# 12     Vinicius Júnior       Real Madrid               0.0659824
# 13     Vinicius Júnior       Real Madrid                0.791789
# 14     Vinicius Júnior       Real Madrid                 1.45161
# 15       Takefusa Kubo          Mallorca                 195.065
# 16       Takefusa Kubo          Mallorca                 2.80277
# 17       Takefusa Kubo          Mallorca                0.311419
# 18       Takefusa Kubo          Mallorca                  1.2846
# 19       Takefusa Kubo          Mallorca                 1.32353
# 20        Takashi Inui             Eibar                 123.612
# 21        Takashi Inui             Eibar                0.826531
# 22        Takashi Inui             Eibar                0.137755
# 23        Takashi Inui             Eibar                0.505102
# 24        Takashi Inui             Eibar                0.872449
# 25      Sergio Canales             Betis                 215.681
# 26      Sergio Canales             Betis                 1.33734
# 27      Sergio Canales             Betis                0.369902
# 28      Sergio Canales             Betis                 1.67879
# 29      Sergio Canales             Betis                  2.1625
# ..                 ...               ...                     ...
# 235       Ángel Correa   Atlético Madrid                 95.9389
# 236       Ángel Correa   Atlético Madrid                 1.79039
# 237       Ángel Correa   Atlético Madrid               0.0873362
# 238       Ángel Correa   Atlético Madrid                0.917031
# 239       Ángel Correa   Atlético Madrid                 1.26638
# 240     Álvaro Vadillo           Granada                 120.739
# 241     Álvaro Vadillo           Granada                 1.47783
# 242     Álvaro Vadillo           Granada                0.221675
# 243     Álvaro Vadillo           Granada                 1.03448
# 244     Álvaro Vadillo           Granada                 1.33005
# 245       Adrián López           Osasuna                  127.36
# 246       Adrián López           Osasuna                0.935551
# 247       Adrián López           Osasuna                 0.12474
# 248       Adrián López           Osasuna                 0.49896
# 249       Adrián López           Osasuna                 1.37214
# 250       Adri Embarba          Espanyol                 161.751
# 251       Adri Embarba          Espanyol                 2.29759
# 252       Adri Embarba          Espanyol                0.459519
# 253       Adri Embarba          Espanyol                 1.05033
# 254       Adri Embarba          Espanyol                 1.18162
# 255      Adnan Januzaj     Real Sociedad                 179.923
# 256      Adnan Januzaj     Real Sociedad                 2.62211
# 257      Adnan Januzaj     Real Sociedad                0.308483
# 258      Adnan Januzaj     Real Sociedad                 1.92802
# 259      Adnan Januzaj     Real Sociedad                 1.69666
# ...
# 4                              Lionel MessiBarcelona
#
#   Player Unique-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[none:Calculation_1642969456954863693:nk]-alias  \
# 0                              Lionel MessiBarcelona
# 1                              Lionel MessiBarcelona
# 2                              Lionel MessiBarcelona
# 3                              Lionel MessiBarcelona
# 4                              Lionel MessiBarcelona
#
#                       Metric Trim-value                  Metric Trim-alias  \
# 0  Shot Creating Actions per 90 minutes              Shot creating actions
# 1                                 xA 90                   Expected assists
# 2     Touches in attacking penalty area  Touches in attacking penalty area
# 3                        Shots Total 90                        Shots Total
# 4                               npxG 90         Non penalty expected goals
#
#   Metric Trim-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[none:Calculation_1642969458000674921:nk]-value  \
# 0               Shot Creating Actions per 90 minutes
# 1                                              xA 90
# 2                  Touches in attacking penalty area
# 3                                     Shots Total 90
# 4                                            npxG 90
#
#   Metric Trim-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[none:Calculation_1642969458000674921:nk]-alias  \
# 0                              Shot creating actions
# 1                                   Expected assists
# 2                  Touches in attacking penalty area
# 3                                        Shots Total
# 4                         Non penalty expected goals
#
#   [P.Player]=[Player] FInal-value [P.Player]=[Player] FInal-alias  \
# 0                            True                            True
# 1                            True                            True
# 2                            True                            True
# 3                            True                            True
# 4                            True                            True
#
#                                                                ...                                                                \
# 0                                                              ...
# 1                                                              ...
# 2                                                              ...
# 3                                                              ...
# 4                                                              ...
#
#   ATTR(Player)-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[attr:Player:nk]-alias  \
# 0                                       Lionel Messi
# 1                                       Lionel Messi
# 2                                       Lionel Messi
# 3                                       Lionel Messi
# 4                                       Lionel Messi
#
#   ATTR(Squad)-alias  \
# 0         Barcelona
# 1         Barcelona
# 2         Barcelona
# 3         Barcelona
# 4         Barcelona
#
#   ATTR(Squad)-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[attr:Squad:nk]-alias  \
# 0                                          Barcelona
# 1                                          Barcelona
# 2                                          Barcelona
# 3                                          Barcelona
# 4                                          Barcelona
#
#   AGG(Pivot Values)-alias  \
# 0                    6.87
# 1                    0.48
# 2                 6.78125
# 3                    4.81
# 4                    0.48
#
#   AGG(Pivot Values)-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[usr:Calculation_1642969456302440458:qk]-alias  \
# 0                                               6.87
# 1                                               0.48
# 2                                            6.78125
# 3                                               4.81
# 4                                               0.48
#
#   AGG(RANK_PERCENTILE([Pivot Values]))-alias  \
# 0                                          1
# 1                                          1
# 2                                   0.961538
# 3                                          1
# 4                                          1
#
#   AGG(RANK_PERCENTILE([Pivot Values]))-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[usr:Calculation_1472677097812692995:qk:10]-alias  \
# 0                                                  1
# 1                                                  1
# 2                                           0.961538
# 3                                                  1
# 4                                                  1
#
#   AGG(RANK_PERCENTILE([Pivot Values]))-value  \
# 0                                          1
# 1                                          1
# 2                                   0.961538
# 3                                          1
# 4                                          1
#
#   AGG(RANK_PERCENTILE([Pivot Values]))-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[usr:Calculation_1472677097812692995:qk:5]-alias  \
# 0                                                  1
# 1                                                  1
# 2                                           0.961538
# 3                                                  1
# 4                                                  1
#
#   AGG(RANK_PERCENTILE([Pivot Values]))-[federated.0bmjchc1bjcyhj1bzk3bf089cnal].[usr:Calculation_1472677097812692995:qk:5]-value
# 0                                                  1
# 1                                                  1
# 2                                           0.961538
# 3                                                  1
# 4                                                  1
#
# [5 rows x 35 columns]
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#      League-value    League-alias
# 0         Serie A         Serie A
# 1  Premier League  Premier League
# 2         Ligue 1         Ligue 1
# 3         La Liga         La Liga
# 4      Bundesliga      Bundesliga
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
#    League-value League-alias       Player-value       Player-alias  \
# 0       La Liga      La Liga      Sergi Roberto      Sergi Roberto
# 1       La Liga      La Liga      Samuel Umtiti      Samuel Umtiti
# 2       La Liga      La Liga      Nélson Semedo      Nélson Semedo
# 3       La Liga      La Liga       Junior Firpo       Junior Firpo
# 4       La Liga      La Liga         Jordi Alba         Jordi Alba
# 5       La Liga      La Liga       Gerard Piqué       Gerard Piqué
# 6       La Liga      La Liga    Clément Lenglet    Clément Lenglet
# 7       La Liga      La Liga    Sergio Busquets    Sergio Busquets
# 8       La Liga      La Liga       Ivan Rakitić       Ivan Rakitić
# 9       La Liga      La Liga    Frenkie de Jong    Frenkie de Jong
# 10      La Liga      La Liga       Arturo Vidal       Arturo Vidal
# 11      La Liga      La Liga        Arthur Melo        Arthur Melo
# 12      La Liga      La Liga       Lionel Messi       Lionel Messi
# 13      La Liga      La Liga        Luis Suárez        Luis Suárez
# 14      La Liga      La Liga  Antoine Griezmann  Antoine Griezmann
#
#    Position - (abbr)-value Position - (abbr)-alias  \
# 0                      DEF                     DEF
# 1                      DEF                     DEF
# 2                      DEF                     DEF
# 3                      DEF                     DEF
# 4                      DEF                     DEF
# 5                      DEF                     DEF
# 6                      DEF                     DEF
# 7                      MID                     MID
# 8                      MID                     MID
# 9                      MID                     MID
# 10                     MID                     MID
# 11                     MID                     MID
# 12                 ATT MID                 ATT MID
# 13                     FWD                     FWD
# 14                     FWD                     FWD
#
#    Position - (1st only)-alias Squad-value Squad-alias
# 0                           DF   Barcelona   Barcelona
# 1                           DF   Barcelona   Barcelona
# 2                           DF   Barcelona   Barcelona
# 3                           DF   Barcelona   Barcelona
# 4                           DF   Barcelona   Barcelona
# 5                           DF   Barcelona   Barcelona
# 6                           DF   Barcelona   Barcelona
# 7                           MF   Barcelona   Barcelona
# 8                           MF   Barcelona   Barcelona
# 9                           MF   Barcelona   Barcelona
# 10                          MF   Barcelona   Barcelona
# 11                          MF   Barcelona   Barcelona
# 12                          FW   Barcelona   Barcelona
# 13                          FW   Barcelona   Barcelona
# 14                          FW   Barcelona   Barcelona
#   MIN(Age #)-alias Player Caps-value Player Caps-alias  \
# 0               33      LIONEL MESSI      LIONEL MESSI
#
#   [P.Squad]=[Squad]-alias Nationality-alias Position - (name)-alias  \
# 0                    True               ARG    Attacking Mid/Winger
#
#   Position-alias Squad-alias
# 0          FW,MF   Barcelona
#   League-value League-alias Matches Played-value Matches Played-alias  \
# 0      La Liga      La Liga                   33                   33
# 1      La Liga      La Liga                   33                   33
# 2      La Liga      La Liga                   33                   33
# 3      La Liga      La Liga                   33                   33
# 4      La Liga      La Liga                   33                   33
# 5      La Liga      La Liga                   33                   33
#
#   Matches Started-value Matches Started-alias SUM(Minutes)-value  \
# 0                    32                    32               2880
# 1                    32                    32               2880
# 2                    32                    32               2880
# 3                    32                    32               2880
# 4                    32                    32               2880
# 5                    32                    32               2880
#
#   SUM(Minutes)-alias                                Measure Names-value  \
# 0               2880  [federated.0css83f1ca35ki15fhdla1pi9lm0].[sum:...
# 1               2880  [federated.0css83f1ca35ki15fhdla1pi9lm0].[sum:...
# 2               2880  [federated.0css83f1ca35ki15fhdla1pi9lm0].[usr:...
# 3               2880  [federated.0css83f1ca35ki15fhdla1pi9lm0].[sum:...
# 4               2880  [federated.0css83f1ca35ki15fhdla1pi9lm0].[sum:...
# 5               2880  [federated.0css83f1ca35ki15fhdla1pi9lm0].[sum:...
#
#   Measure Names-alias Measure Values-alias
# 0           Red Cards                    0
# 1        Yellow Cards                    4
# 2   Pass Completion %                  79%
# 3           Penalties                    5
# 4             Assists                   20
# 5               Goals                   25
#    League-value League-alias      Squad-value      Squad-alias
# 0       La Liga      La Liga       Villarreal       Villarreal
# 1       La Liga      La Liga       Valladolid       Valladolid
# 2       La Liga      La Liga         Valencia         Valencia
# 3       La Liga      La Liga          Sevilla          Sevilla
# 4       La Liga      La Liga    Real Sociedad    Real Sociedad
# 5       La Liga      La Liga      Real Madrid      Real Madrid
# 6       La Liga      La Liga          Osasuna          Osasuna
# 7       La Liga      La Liga         Mallorca         Mallorca
# 8       La Liga      La Liga          Levante          Levante
# 9       La Liga      La Liga          Leganés          Leganés
# 10      La Liga      La Liga          Granada          Granada
# 11      La Liga      La Liga           Getafe           Getafe
# 12      La Liga      La Liga         Espanyol         Espanyol
# 13      La Liga      La Liga            Eibar            Eibar
# 14      La Liga      La Liga       Celta Vigo       Celta Vigo
# 15      La Liga      La Liga            Betis            Betis
# 16      La Liga      La Liga        Barcelona        Barcelona
# 17      La Liga      La Liga  Atlético Madrid  Atlético Madrid
# 18      La Liga      La Liga    Athletic Club    Athletic Club
# 19      La Liga      La Liga           Alavés           Alavés
